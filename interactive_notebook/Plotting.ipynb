# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [2, 5, 3])
plt.xlabel("x values")
plt.ylabel("y values")
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("http://atlas.marine.ie/midata/OceanFeatures/Celtic_Explorer_Underway.csv.zip")

# %%
df.columns
# Out:
# Index(['WKT', 'gml_id', 'OBJECTID', 'beginLifespanVersion',
#        'endLifespanVersion', 'datasetName', 'localId', 'inspireId',
#        'inspireTheme', 'version', 'description', 'longitude', 'latitude',
#        'depth', 'depthUoM', 'value_', 'observedProperty',
#        'observedPropertyUoM', 'resultQuality', 'resultTime', 'validTime',
#        'process', 'scale', 'coordinateReferenceSystem',
#        'styleLayerDescription', 'licence', 'dataProvenance', 'dataAccessUrl'],
#       dtype='object')

# %%
df['description']
# Out:
# 0        Underway SBE 21 thermosalinograph sea surface ...
# 1        Underway SBE 21 thermosalinograph sea surface ...
# 2        Underway SBE 21 thermosalinograph sea surface ...
# 3        Underway SBE 21 thermosalinograph sea surface ...
# 4        Underway SBE 21 thermosalinograph sea surface ...
#                                ...
# 20840    Underway SBE 21 thermosalinograph sea surface ...
# 20841    Underway SBE 21 thermosalinograph sea surface ...
# 20842    Underway SBE 21 thermosalinograph sea surface ...
# 20843    Underway SBE 21 thermosalinograph sea surface ...
# 20844    Underway SBE 21 thermosalinograph sea surface ...
# Name: description, Length: 20845, dtype: object

# %%
df['description'].head()
# Out:
# 0    Underway SBE 21 thermosalinograph sea surface ...
# 1    Underway SBE 21 thermosalinograph sea surface ...
# 2    Underway SBE 21 thermosalinograph sea surface ...
# 3    Underway SBE 21 thermosalinograph sea surface ...
# 4    Underway SBE 21 thermosalinograph sea surface ...
# Name: description, dtype: object

# %%
df.head()
# Out:
#                             WKT  gml_id  OBJECTID beginLifespanVersion  \
# 0   POINT (-0.579216 57.548075)  F91__1         1  2017-01-17T03:00:00
# 1    POINT (8.107573 54.784784)  F91__2         2  2017-01-22T00:00:00
# 2    POINT (9.955458 54.341287)  F91__3         3  2017-01-26T21:00:00
# 3    POINT (3.653541 55.749509)  F91__4         4  2017-02-01T15:00:00
# 4  POINT (-15.864965 53.071753)  F91__5         5  2017-02-10T21:00:00
#
#     endLifespanVersion                               datasetName    localId  \
# 0  2018-01-25T09:00:00  Celtic Explorer Underway Sea Temperature  CESeaTemp
# 1  2018-01-25T09:00:00  Celtic Explorer Underway Sea Temperature  CESeaTemp
# 2  2018-01-25T09:00:00  Celtic Explorer Underway Sea Temperature  CESeaTemp
# 3  2018-01-25T09:00:00  Celtic Explorer Underway Sea Temperature  CESeaTemp
# 4  2018-01-25T09:00:00  Celtic Explorer Underway Sea Temperature  CESeaTemp
#
#                                            inspireId  \
# ...

# %%
df['value_'].unique()
# Out:
# array([ 8.163,  4.261,  3.108, ..., 13.106, 13.405, 13.247])

# %%
df['value_'].hist(color='g');
plt.xlabel('SST (Degrees celsius)')
plt.title('Distribution of Sea Surface Temperature')
# Out:
# Text(0.5, 1.0, 'Distribution of Sea Surface Temperature')

# %%
plt.style.use('ggplot')
df['value_'].hist(color='g');
plt.xlabel('SST (Degrees celsius)')
plt.title('Distribution of Sea Surface Temperature')
# Out:
# Text(0.5, 1.0, 'Distribution of Sea Surface Temperature')

# %%
time = [0, 1, 2, 3]
position = [0, 10, 20, 30]

# %%
table = pd.DataFrame({'Time': time, 'Position': position})

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
type(table['Position'])
# Out:
# pandas.core.series.Series

# %%
table.plot();
